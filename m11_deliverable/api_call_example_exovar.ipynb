# %% [markdown]
# Check Python version

# %%
# !python --version
# Out:
# Python 3.9.18

# %% [markdown]
# Import libraries

# %%
import json
import yaml
import requests
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# ### Air Quality and Temperature Data
#
# This dataset pertains to air quality and temperature data. It was taken from the UCI Machine Learning Repository: [UCI ML Repository](https://archive.ics.uci.edu/ml/index.php)

# %%
file_name = 'air_quality.csv'

# %%
dataset = pd.read_csv(file_name)

# %%
dataset=dataset.head(500)
dataset.shape
# Out:
# (500, 14)

# %%
dataset.columns
# Out:
# Index(['datetime', 'CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)',
#        'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)',
#        'PT08.S5(O3)', 'RH', 'AH', 'T'],
#       dtype='object')

# %%
dataset.head()
# Out:
#            datetime  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  \
# 0  10-03-2004 18:00     2.6         1360       150      11.9           1046
# 1  10-03-2004 19:00     2.0         1292       112       9.4            955
# 2  10-03-2004 20:00     2.2         1402        88       9.0            939
# 3  10-03-2004 21:00     2.2         1376        80       9.2            948
# 4  10-03-2004 22:00     1.6         1272        51       6.5            836
#
#    NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)    RH      AH  \
# 0      166          1056      113          1692         1268  48.9  0.7578
# 1      103          1174       92          1559          972  47.7  0.7255
# 2      131          1140      114          1555         1074  54.0  0.7502
# 3      172          1092      122          1584         1203  60.0  0.7867
# 4      131          1205      116          1490         1110  59.6  0.7888
#
#       T
# 0  13.6
# 1  13.3
# 2  11.9
# 3  11.0
# 4  11.2

# %%
dataset.tail()
# Out:
#              datetime  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  \
# 495  31-03-2004 09:00     2.2         1262       216       8.6            924
# 496  31-03-2004 10:00     1.7         1197       117       6.5            837
# 497  31-03-2004 11:00     1.9         1277       156       7.7            886
# 498  31-03-2004 12:00     2.9         1430       332      11.3           1025
# 499  31-03-2004 13:00     2.2         1242       232       9.1            944
#
#      NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)    RH      AH  \
# 495      181           872      125          1576         1093  74.4  0.9384
# 496      144           957      118          1498          965  71.0  0.9582
# 497      140           902      109          1579         1004  70.0  0.9924
# 498      204           779      123          1772         1166  73.3  1.0442
# 499      149           846      114          1638          991  78.1  1.0411
#
#         T
# 495  10.4
# 496  11.5
# 497  12.2
# 498  12.3
# 499  11.3

# %% [markdown]
# Define the required time and target columns

# %%
time_col = dataset.columns[0]
dataset[time_col] = pd.to_datetime(dataset[time_col], format="%d-%m-%Y %H:%M", errors='coerce')
time_col = dataset.columns[0]
target_col = dataset.columns[-1]
dataset[time_col] = dataset[time_col].astype(str)

# %% [markdown]
# Change target column to float

# %%
# dataset[target_col] = dataset[target_col].astype(float)

# %%
# dataset.head()

# %% [markdown]
# Split dataset into train and test sets

# %%
train_size = 0.9
train_points = int(train_size*len(dataset))
train_df = dataset.iloc[:train_points]
test_df = dataset.iloc[train_points:]

# %% [markdown]
# Plot graph

# %%
figsize = (16, 8)
train_df.set_index(time_col)[target_col].plot(figsize=figsize);

# %% [markdown]
# ### **Train API**

# %% [markdown]
# Train data: convert df to list-of-list

# %%
train_data = []
for value in train_df.values:
    train_data.append(list(value))

# %%
train_data[:2]
# Out:
# [['2004-03-10 18:00:00',
#   2.6,
#   1360,
#   150,
#   11.9,
#   1046,
#   166,
#   1056,
#   113,
#   1692,
#   1268,
#   48.9,
#   0.7578,
#   13.6],
#  ['2004-03-10 19:00:00',
#   2.0,
#   1292,
#   112,
#   9.4,
#   955,
#   103,
#   1174,
#   92,
#   1559,
#   972,
#   47.7,
#   0.7255,
#   13.3]]

# %% [markdown]
# Custom Model Request (optional)

# %%
# Default model request

# Customized model request
model_request = {
    'type': 'meta_wa',  # 'meta_naive', 'meta_wa'
    'scorers': ['mase', 'smape'],
    'params': {
        'preprocessors': [
            # {'type': 'dartsimputer'},
            # {'type': 'simpleimputer', 'params': {'strategy': 'mean'}},
            {'type': 'minmaxscaler'},
        ],
        'base_models': [
            # {'type': 'darts_rnn',
            #  'params': {
            #      'model': 'LSTM',
            #      'hidden_dim': 10,
            #      'n_rnn_layers': 3
            # }},
            # {'type': 'darts_tcn',
            #  'params': {
            #      'output_chunk_length': 24,
            #      'input_chunk_length': 48,                 
            #      'n_epochs': 100,
            # }},
            #     {'type': 'darts_rnn',
            #  'params': {
            #      'model': 'LSTM',
            #      'hidden_dim': 10,
            #      'n_rnn_layers': 3
            # }},
            # {'type': 'darts_tsmixer'},            
            # {'type': 'darts_dlinear'},
            #  {'type': 'darts_blockrnn'},
            #  {'type': 'darts_tcn'},
            {'type': 'darts_tsmixer'},
            {'type': 'darts_tide'}
        ],
    },
}

# %% [markdown]
# This is for JSON model_request

# %%
# file_path = 'model_request.json'
# # For writing the model request to a json file
# with open(file_path, 'r') as file:
#     model_request = json.load(file)

# %% [markdown]
# This is for YAML model_request

# %%
# file_path = 'model_request.yaml'
# # For reading the model request from a yaml file
# with open(file_path, 'r') as file:
#     model_request = yaml.safe_load(file)

# %% [markdown]
# Train API JSON Payload

# %%
api_json = {
    'data': train_data,
    'model': model_request  # (optional) can be commented out
}

# %% [markdown]
# Build URL

# %%
with open('url.yaml', 'r') as file:
    url_dict = yaml.safe_load(file)

# %%
# URL to our SYBIL AWS service
protocol = url_dict['protocol']
host = url_dict['host']
port = url_dict['port']
endpoint = 'train'

url = '%s://%s:%s/%s' % (protocol, host, str(port), endpoint)

# %%
# protocol, host, port

# %% [markdown]
# Call endpoint, receive response JSON, write to output file

# %%
# %%time
response = requests.post(url, json=api_json)
print(response)
print()
# Out:
# <Response [200]>
#
# CPU times: user 81.3 ms, sys: 42.3 ms, total: 124 ms
# Wall time: 4min 32s

# %%
train_json_out = response.json()  # dict output
# train_json_out

# %% [markdown]
# ### **Forecast API**

# %% [markdown]
# Forecast Dates: predict the next 32 years of temperature anomaly data (1980-2012)

# %%
test_data = []
for value in test_df.drop(columns=target_col).values:
    test_data.append(list(value))

# %%
test_data[:2]
# Out:
# [['2004-03-29 12:00:00',
#   1.4,
#   971,
#   91,
#   5.5,
#   786,
#   92,
#   1129,
#   78,
#   1272,
#   546,
#   29.0,
#   0.5406],
#  ['2004-03-29 13:00:00',
#   1.6,
#   1010,
#   146,
#   6.5,
#   833,
#   91,
#   1070,
#   83,
#   1332,
#   561,
#   27.9,
#   0.5517]]

# %% [markdown]
# Model from Train API

# %%
model = train_json_out['model']

# %% [markdown]
# Forecast API JSON Payload

# %%
api_json = {
    'model': model,
    'data': test_data
}

# %% [markdown]
# Build URL (same as train except for the endpoint)

# %%
endpoint = 'forecast'

url = '%s://%s:%s/%s' % (protocol, host, str(port), endpoint)

# %% [markdown]
# Call endpoint, receive response JSON, write to output file

# %%
# %%time
response = requests.post(url, json=api_json)
print(response)
print()
# Out:
# <Response [200]>
#
# CPU times: user 52.1 ms, sys: 5.18 ms, total: 57.3 ms
# Wall time: 3.04 s

# %%
forecast_json_out = response.json()  # dict output
forecast_json_out
# Out:
# {'data': [['2004-03-29 12:00:00', 17.42917794492088],
#   ['2004-03-29 13:00:00', 16.731980567009995],
#   ['2004-03-29 14:00:00', 17.01967245936741],
#   ['2004-03-29 15:00:00', 16.531899143888218],
#   ['2004-03-29 16:00:00', 15.789627842256188],
#   ['2004-03-29 17:00:00', 15.233816889214202],
#   ['2004-03-29 18:00:00', 15.316622769229866],
#   ['2004-03-29 19:00:00', 14.151377675301674],
#   ['2004-03-29 20:00:00', 13.317630784015865],
#   ['2004-03-29 21:00:00', 12.521160297905535],
#   ['2004-03-29 22:00:00', 11.7655696334282],
#   ['2004-03-29 23:00:00', 10.95342052958604],
#   ['2004-03-30 00:00:00', 11.3371646814178],
#   ['2004-03-30 01:00:00', 10.935306990635413],
#   ['2004-03-30 02:00:00', 10.463130435049756],
#   ['2004-03-30 03:00:00', 10.96113599892752],
#   ['2004-03-30 04:00:00', 10.741224688422825],
#   ['2004-03-30 05:00:00', 10.529602890231658],
#   ['2004-03-30 06:00:00', 9.921521418365526],
#   ['2004-03-30 07:00:00', 10.175212175334266],
#   ['2004-03-30 08:00:00', 11.492110639842247],
#   ['2004-03-30 09:00:00', 12.969214595437967],
#   ['2004-03-30 10:00:00', 14.650107712149943],
#   ['2004-03-30 11:00:00', 15.47872432109508],
#   ['2004-03-30 12:00:00', 17.552049360557234],
#   ['2004-03-30 13:00:00', 17.636649258685864],
#   ['2004-03-30 14:00:00', 17.111455371352204],
#   ['2004-03-30 15:00:00', 17.0423163993397],
#   ['2004-03-30 16:00:00', 16.03219463090381],
#   ['2004-03-30 17:00:00', 14.887394186827306],
#   ['2004-03-30 18:00:00', 13.512460444449886],
#   ['2004-03-30 19:00:00', 12.354881960755682],
#   ['2004-03-30 20:00:00', 12.252477195668549],
#   ['2004-03-30 21:00:00', 11.500728880656048],
#   ['2004-03-30 22:00:00', 11.311760308843114],
#   ['2004-03-30 23:00:00', 10.790083011379615],
#   ['2004-03-31 00:00:00', 11.056697719728184],
#   ['2004-03-31 01:00:00', 10.596194492320546],
#   ['2004-03-31 02:00:00', 10.459193463347653],
#   ['2004-03-31 03:00:00', 9.910244911575264],
#   ['2004-03-31 04:00:00', 9.090626569630158],
#   ['2004-03-31 05:00:00', 9.179600758442561],
#   ['2004-03-31 06:00:00', 8.724013776731056],
#   ['2004-03-31 07:00:00', 8.619472315213585],
#   ['2004-03-31 08:00:00', 9.600263344699776],
#   ['2004-03-31 09:00:00', 11.724446506440437],
#   ['2004-03-31 10:00:00', 13.012488561283766],
#   ['2004-03-31 11:00:00', 15.335474786353364],
#   ['2004-03-31 12:00:00', 16.88497206514536],
#   ['2004-03-31 13:00:00', 18.519020109579742]]}

# %% [markdown]
# Combine forecast dates and output

# %%
forecast_df = pd.DataFrame(
    data=forecast_json_out['data'],
    columns=[time_col, target_col],
)

# %%
forecast_df.shape
# Out:
# (50, 2)

# %%
forecast_df.columns
# Out:
# Index(['datetime', 'T'], dtype='object')

# %%
forecast_df.head()
# Out:
#               datetime          T
# 0  2004-03-29 12:00:00  17.429178
# 1  2004-03-29 13:00:00  16.731981
# 2  2004-03-29 14:00:00  17.019672
# 3  2004-03-29 15:00:00  16.531899
# 4  2004-03-29 16:00:00  15.789628

# %%
forecast_df.tail()
# Out:
#                datetime          T
# 45  2004-03-31 09:00:00  11.724447
# 46  2004-03-31 10:00:00  13.012489
# 47  2004-03-31 11:00:00  15.335475
# 48  2004-03-31 12:00:00  16.884972
# 49  2004-03-31 13:00:00  18.519020

# %% [markdown]
# Plot train and forecast side-by-side

# %%
train_df['color'] = 'b'
train_df.set_index(time_col)[target_col].plot(figsize=figsize, color=train_df['color']);
# Out:
# /tmp/ipykernel_1658713/2998340865.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['color'] = 'b'

# %%
forecast_df['color'] = 'r'
forecast_df.set_index(time_col).plot(figsize=figsize, color=forecast_df['color']);

# %% [markdown]
# Combine train and forecast sets

# %%
df = pd.concat([train_df, forecast_df]).reset_index(drop=True)

# %%
df.shape
# Out:
# (500, 15)

# %%
df.head()
# Out:
#               datetime  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  2004-03-10 18:00:00     2.6       1360.0     150.0      11.9
# 1  2004-03-10 19:00:00     2.0       1292.0     112.0       9.4
# 2  2004-03-10 20:00:00     2.2       1402.0      88.0       9.0
# 3  2004-03-10 21:00:00     2.2       1376.0      80.0       9.2
# 4  2004-03-10 22:00:00     1.6       1272.0      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#      RH      AH     T color
# 0  48.9  0.7578  13.6     b
# 1  47.7  0.7255  13.3     b
# 2  54.0  0.7502  11.9     b
# 3  60.0  0.7867  11.0     b
# 4  59.6  0.7888  11.2     b

# %%
df.tail()
# Out:
#                 datetime  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 495  2004-03-31 09:00:00     NaN          NaN       NaN       NaN
# 496  2004-03-31 10:00:00     NaN          NaN       NaN       NaN
# 497  2004-03-31 11:00:00     NaN          NaN       NaN       NaN
# 498  2004-03-31 12:00:00     NaN          NaN       NaN       NaN
# 499  2004-03-31 13:00:00     NaN          NaN       NaN       NaN
#
#      PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 495            NaN      NaN           NaN      NaN           NaN          NaN
# 496            NaN      NaN           NaN      NaN           NaN          NaN
# 497            NaN      NaN           NaN      NaN           NaN          NaN
# 498            NaN      NaN           NaN      NaN           NaN          NaN
# 499            NaN      NaN           NaN      NaN           NaN          NaN
#
#      RH  AH          T color
# 495 NaN NaN  11.724447     r
# 496 NaN NaN  13.012489     r
# 497 NaN NaN  15.335475     r
# 498 NaN NaN  16.884972     r
# 499 NaN NaN  18.519020     r

# %% [markdown]
# Plot combined train and forecast sets with the vertical black line as the cut-off

# %%
df.set_index(time_col)[target_col].plot(figsize=figsize, color='r')
plt.axvline(x=len(train_df), color='black', label='Train/Forecast set cut-off')
plt.text(x=len(train_df)-9, y=forecast_df[target_col].max(), s='Train', fontweight='bold', fontsize=14)
plt.text(x=len(train_df)+1, y=forecast_df[target_col].max(), s='Forecast', fontweight='bold', fontsize=14)
plt.ylabel(ylabel='Temperature (' + u'\N{DEGREE SIGN}' + 'C)')
plt.title(label='Hourly Recorded Temperature', fontweight='bold', fontsize=20)
plt.show();

# %% [markdown]
# Plot original dataset to compare

# %%
figsize = (16, 8)
dataset.set_index(time_col)[target_col].plot(figsize=figsize);
plt.ylabel(ylabel='Temperature (' + u'\N{DEGREE SIGN}' + 'C)')
plt.title(label='Hourly Recorded Temperature', fontweight='bold', fontsize=20)
plt.show();

# %% [markdown]
# Plot original dataset (blue) with SYBIL forecasted values (red)

# %%
df.set_index(time_col)[target_col].plot(figsize=figsize, color='r')
dataset.set_index(time_col)[target_col].plot(figsize=figsize);
plt.axvline(x=len(train_df), color='black', label='Train/Forecast set cut-off')
plt.text(x=len(train_df)-9, y=forecast_df[target_col].max(), s='Train', fontweight='bold', fontsize=14)
plt.text(x=len(train_df)+1, y=forecast_df[target_col].max(), s='Forecast', fontweight='bold', fontsize=14)
plt.ylabel(ylabel='Temperature (' + u'\N{DEGREE SIGN}' + 'C)')
plt.title(label='Hourly Recorded Temperature ', fontweight='bold', fontsize=20)
plt.show();
